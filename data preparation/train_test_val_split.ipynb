# %%
import sys
import os

from google.colab import drive
drive.mount('/content/drive')

! pip install python_splitter 

import python_splitter
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
data = '/content/drive/MyDrive/Daan Thesis Colab Notebooks/Case_study/datasets/preprocess_set/5_sets/Train_Test_Folder/train'

python_splitter.split_from_folder(data, train=0.33, test=0.33, val=0.34)
# Out:
# ✅Checking SOURCE directory...
# 0.33 0.34 0.33
# ✅Checking percentage validation...
# ✅Making required directories...
# ✅Shuffling data...
# ✅Getting ready for copying files...
#
# -------------Successfully splitted !!!---------------
